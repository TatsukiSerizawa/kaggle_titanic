# %%
import warnings
warnings.filterwarnings('ignore') # warningが出ないように設定

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import missingno as msno
from sklearn.preprocessing import LabelEncoder

# %matplotlib inline


pd.set_option("display.max_rows", None) # pandasの表示上限をなくす
pd.set_option("display.max_columns", None) # pandasの表示上限をなくす

# %%
#lgbSubmission.csv: PassengerId	Pclass	Sex	SibSp	Parch	Fare で学習
#lgbSubmission2.csv: Pclass	Sex	Age	SibSp	Parch	Fare で学習
#lgbSubmission3.csv: Pclass	Sex	Age	SibSp	Parch	Fare	Embarked で学習
#lgbSubmission4.csv:

# %%
data_path = './data/'

train = pd.read_csv(data_path + 'train.csv')
test = pd.read_csv(data_path + 'test.csv')
pd.set_option("display.max_columns",1000)

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
test.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
msno.matrix(train)

# %%
## 欠損値の数と割合を返す
def missing_columns(df):
    total = df.isnull().sum().sort_values(ascending = False)
    percent = (df.isnull().sum()/df.isnull().count()*100).sort_values(ascending = False)
    missing_data  = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
    return missing_data

# %%
missing_columns(train)
# Out:
#              Total    Percent
# Cabin          687  77.104377
# Age            177  19.865320
# Embarked         2   0.224467
# Fare             0   0.000000
# Ticket           0   0.000000
# Parch            0   0.000000
# SibSp            0   0.000000
# Sex              0   0.000000
# Name             0   0.000000
# Pclass           0   0.000000
# Survived         0   0.000000
# PassengerId      0   0.000000

# %%
missing_columns(test)
# Out:
#              Total    Percent
# Cabin          327  78.229665
# Age             86  20.574163
# Fare             1   0.239234
# Embarked         0   0.000000
# Ticket           0   0.000000
# Parch            0   0.000000
# SibSp            0   0.000000
# Sex              0   0.000000
# Name             0   0.000000
# Pclass           0   0.000000
# PassengerId      0   0.000000

# %%
#Cabinは欠損値が多すぎる、PassengerId、Nameは関係ない、Embarked、Ticketは処理がよくわからないので特徴削除
train = train.drop(columns=['PassengerId', 'Name', 'Cabin', 'Ticket'])
test = test.drop(columns=['PassengerId', 'Name', 'Cabin', 'Ticket'])

# %%
pd.value_counts(train['Embarked'])
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
#最頻値代入
train["Embarked"] = train["Embarked"].fillna("S")

# %%
#カテゴリ変数の変換
LE=LabelEncoder()

labels = ['Embarked','Sex']
for label in labels:
    train[label]=LE.fit_transform(train[label])
    test[label]=LE.fit_transform(test[label])

# %%
train.head()
# Out:
#    Survived  Pclass  Sex   Age  SibSp  Parch     Fare  Embarked
# 0         0       3    1  22.0      1      0   7.2500         2
# 1         1       1    0  38.0      1      0  71.2833         0
# 2         1       3    0  26.0      0      0   7.9250         2
# 3         1       1    0  35.0      1      0  53.1000         2
# 4         0       3    1  35.0      0      0   8.0500         2

# %%
missing_columns(train)
# Out:
#           Total   Percent
# Age         177  19.86532
# Embarked      0   0.00000
# Fare          0   0.00000
# Parch         0   0.00000
# SibSp         0   0.00000
# Sex           0   0.00000
# Pclass        0   0.00000
# Survived      0   0.00000

# %%
train = train.fillna(train.mean()) # 平均値代入
test = test.fillna(test.mean()) # 平均値代入

# %%
missing_columns(train)
# Out:
#           Total  Percent
# Embarked      0      0.0
# Fare          0      0.0
# Parch         0      0.0
# SibSp         0      0.0
# Age           0      0.0
# Sex           0      0.0
# Pclass        0      0.0
# Survived      0      0.0

# %%
#train data と test data をそれぞれ特徴量とラベルに分ける
from sklearn.model_selection import train_test_split
trainFeatures = train.drop(columns='Survived')
trainLabels = train.Survived

# %%
#light gbm 用データ分割
X_train, X_test, y_train, y_test = train_test_split(trainFeatures, trainLabels, test_size=0.2, random_state=72)

#モデル用dataset生成
import lightgbm as lgb
lgbTrain = lgb.Dataset(X_train, y_train)
lgbTest = lgb.Dataset(X_test, y_test)
lgbFinalTrain = lgb.Dataset(trainFeatures, trainLabels)

# %%
#light gbm

lgbParams = {
    'boosting': 'dart',          # dart (drop out trees) often performs better
    'application': 'binary',     # Binary classification
    'learning_rate': 0.02,       # Learning rate, controls size of a gradient descent step
    'min_data_in_leaf': 20,      # Data set is quite small so reduce this a bit
    'feature_fraction': 0.7,     # Proportion of features in each boost, controls overfitting
    'num_leaves': 41,            # Controls size of tree since LGBM uses leaf wise splits
    'metric': 'binary_logloss',  # Area under ROC curve as the evaulation metric
    'drop_rate': 0.15
}

#学習
evaluationResults = {}
lgbModel = lgb.train(train_set=lgbTrain,
                     params=lgbParams,
                     valid_sets=[lgbTrain, lgbTest], 
                     valid_names=['Train', 'Test'],
                     evals_result=evaluationResults,
                     num_boost_round=500,
                     early_stopping_rounds=100,
                     verbose_eval=20
                    )

optimum_boost_rounds = lgbModel.best_iteration
# Out:
# Training until validation scores don't improve for 100 rounds.
# [20]	Train's binary_logloss: 0.575925	Test's binary_logloss: 0.590254
# [40]	Train's binary_logloss: 0.530654	Test's binary_logloss: 0.544281
# [60]	Train's binary_logloss: 0.521205	Test's binary_logloss: 0.536443
# [80]	Train's binary_logloss: 0.506059	Test's binary_logloss: 0.523504
# [100]	Train's binary_logloss: 0.497013	Test's binary_logloss: 0.513905
# [120]	Train's binary_logloss: 0.492339	Test's binary_logloss: 0.511185
# [140]	Train's binary_logloss: 0.478479	Test's binary_logloss: 0.499318
# [160]	Train's binary_logloss: 0.480738	Test's binary_logloss: 0.502432
# [180]	Train's binary_logloss: 0.458872	Test's binary_logloss: 0.483172
# [200]	Train's binary_logloss: 0.442976	Test's binary_logloss: 0.471712
# [220]	Train's binary_logloss: 0.433906	Test's binary_logloss: 0.465297
# [240]	Train's binary_logloss: 0.418964	Test's binary_logloss: 0.452886
# [260]	Train's binary_logloss: 0.411851	Test's binary_logloss: 0.447883
# [280]	Train's binary_logloss: 0.407722	Test's binary_logloss: 0.448786
# [300]	Train's binary_logloss: 0.403767	Test's binary_logloss: 0.447655
# [320]	Train's binary_logloss: 0.397817	Test's binary_logloss: 0.442402
# [340]	Train's binary_logloss: 0.394164	Test's binary_logloss: 0.43906
# [360]	Train's binary_logloss: 0.397557	Test's binary_logloss: 0.439791
# [380]	Train's binary_logloss: 0.391647	Test's binary_logloss: 0.437468
# [400]	Train's binary_logloss: 0.38481	Test's binary_logloss: 0.433729
# [420]	Train's binary_logloss: 0.380115	Test's binary_logloss: 0.431024
# [440]	Train's binary_logloss: 0.372656	Test's binary_logloss: 0.425547
# [460]	Train's binary_logloss: 0.369463	Test's binary_logloss: 0.424938
# [480]	Train's binary_logloss: 0.356516	Test's binary_logloss: 0.419797
# [500]	Train's binary_logloss: 0.356492	Test's binary_logloss: 0.420821
# Did not meet early stopping. Best iteration is:
# [485]	Train's binary_logloss: 0.355721	Test's binary_logloss: 0.419795

# %%
fig, axs = plt.subplots(1, 2, figsize=[15, 4])

# Plot the log loss during training
axs[0].plot(evaluationResults['Train']['binary_logloss'], label='Train')
axs[0].plot(evaluationResults['Test']['binary_logloss'], label='Test')
axs[0].set_ylabel('Log loss')
axs[0].set_xlabel('Boosting round')
axs[0].set_title('Training performance')
axs[0].legend()

# Plot feature importance
importances = pd.DataFrame({'features': lgbModel.feature_name(), 
                            'importance': lgbModel.feature_importance()}).sort_values('importance', ascending=False)
axs[1].bar(x=np.arange(len(importances)), height=importances['importance'])
axs[1].set_xticks(np.arange(len(importances)))
axs[1].set_xticklabels(importances['features'])
axs[1].set_ylabel('Feature importance (# times used to split)')
axs[1].set_title('Feature importance')

plt.show()

# %%
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score
preds = np.round(lgbModel.predict(X_test))
print('Accuracy score = \t {}'.format(accuracy_score(y_test, preds)))
print('Precision score = \t {}'.format(precision_score(y_test, preds)))
print('Recall score =   \t {}'.format(recall_score(y_test, preds)))
print('F1 score =      \t {}'.format(f1_score(y_test, preds)))
# Out:
# Accuracy score = 	 0.8324022346368715
# Precision score = 	 0.8088235294117647
# Recall score =   	 0.7638888888888888
# F1 score =      	 0.7857142857142858

# %%
#予測用datasetで予測
lgbFinal = lgb.train(train_set=lgbFinalTrain,
                      params=lgbParams,
                      num_boost_round=optimum_boost_rounds,
                      verbose_eval=0
                      )

lgbPred = np.round(lgbFinal.predict(test)).astype(int)

# %%
# テスト値を再読み込みして，randomForestでクラス分類したカラムを追加
df_out = pd.read_csv("./data/test.csv")
lgbPred = pd.Series(lgbPred)
df_out["Survived"] = lgbPred

# outputディレクトリに出力する
df_out[["PassengerId","Survived"]].to_csv("./data/lgbSubmission3.csv",index=False)

# %%
#特徴量選択してもう一回

# %%
trainCp = train
testCp = test

# %%
#train data と test data をそれぞれ特徴量とラベルに分ける
trainFeatures = trainCp.drop(columns='Survived')
trainLabels = trainCp.Survived

# %%
#SFSでの特徴選択
from sklearn.neighbors import KNeighborsClassifier
from mlxtend.feature_selection import SequentialFeatureSelector as SFS
from mlxtend.plotting import plot_sequential_feature_selection as plot_sfs
import matplotlib.pyplot as plt

knn = KNeighborsClassifier(n_neighbors=4)

sfs = SFS(knn, #学習器
          k_features=7, #特徴の最大選択数
          forward=True, #Trueでforward selection, Falseでback
          floating=False, #forward selectionの亜種を行うためのもの
          scoring='accuracy', #評価指標
          cv=5) #クロスバリデーション(cv=0とすると、最終的に選ばれる特徴が変わる)

sfs = sfs.fit(trainFeatures, trainLabels)

fig1 = plot_sfs(sfs.get_metric_dict(), kind='std_dev')

plt.ylim([0.7, 0.9])
plt.grid()
plt.show()

# %%
sfs = sfs.fit(trainFeatures, trainLabels)
sfs.subsets_
# Out:
# {1: {'avg_score': 0.6646253068050885,
#   'cv_scores': array([0.60335196, 0.60893855, 0.66853933, 0.71348315, 0.72881356]),
#   'feature_idx': (0,),
#   'feature_names': ('Pclass',)},
#  2: {'avg_score': 0.7734015725301238,
#   'cv_scores': array([0.74860335, 0.72625698, 0.80898876, 0.78089888, 0.80225989]),
#   'feature_idx': (0, 1),
#   'feature_names': ('Pclass', 'Sex')},
#  3: {'avg_score': 0.7722340375354592,
#   'cv_scores': array([0.72625698, 0.7877095 , 0.76966292, 0.7752809 , 0.80225989]),
#   'feature_idx': (0, 1, 4),
#   'feature_names': ('Pclass', 'Sex', 'Parch')},
#  4: {'avg_score': 0.790148794926709,
#   'cv_scores': array([0.74301676, 0.82681564, 0.79213483, 0.78651685, 0.80225989]),
#   'feature_idx': (0, 1, 4, 6),
#   'feature_names': ('Pclass', 'Sex', 'Parch', 'Embarked')},
#  5: {'avg_score': 0.7621529214795302,
#   'cv_scores': array([0.72625698, 0.74860335, 0.76966292, 0.7752809 , 0.79096045]),
#   'feature_idx': (0, 1, 3, 4, 6),
#   'feature_names': ('Pclass', 'Sex', 'SibSp', 'Parch', 'Embarked')},
#  6: {'avg_score': 0.7576334311776032,
#   'cv_scores': array([0.74301676, 0.75418994, 0.76404494, 0.73595506, 0.79096045]),
#   'feature_idx': (0, 1, 2, 3, 4, 6),
#   'feature_names': ('Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Embarked')},
#  7: {'avg_score': 0.6947548875145534,
#   'cv_scores': array([0.67039106, 0.69832402, 0.69662921, 0.70786517, 0.70056497]),
#   'feature_idx': (0, 1, 2, 3, 4, 5, 6),
#   'feature_names': ('Pclass',
#    'Sex',
#    'Age',
#    'SibSp',
#    'Parch',
#    'Fare',
#    'Embarked')}}

# %%
#SFSの結果より4つの特徴を選択
trainFeatures = trainFeatures.drop(columns=['SibSp', 'Age', 'Fare'])
testCp = testCp.drop(columns=['SibSp', 'Age', 'Fare'])

# %%
trainFeatures.head()
# Out:
#    Pclass  Sex  Parch  Embarked
# 0       3    1      0         2
# 1       1    0      0         0
# 2       3    0      0         2
# 3       1    0      0         2
# 4       3    1      0         2

# %%
#light gbm 用データ分割
X_train, X_test, y_train, y_test = train_test_split(trainFeatures, trainLabels, test_size=0.2, random_state=72)

#モデル用dataset生成
import lightgbm as lgb
lgbTrain = lgb.Dataset(X_train, y_train)
lgbTest = lgb.Dataset(X_test, y_test)
lgbFinalTrain = lgb.Dataset(trainFeatures, trainLabels)

# %%
#light gbm

lgbParams = {
    'boosting': 'dart',          # dart (drop out trees) often performs better
    'application': 'binary',     # Binary classification
    'learning_rate': 0.02,       # Learning rate, controls size of a gradient descent step
    'min_data_in_leaf': 20,      # Data set is quite small so reduce this a bit
    'feature_fraction': 0.7,     # Proportion of features in each boost, controls overfitting
    'num_leaves': 41,            # Controls size of tree since LGBM uses leaf wise splits
    'metric': 'binary_logloss',  # Area under ROC curve as the evaulation metric
    'drop_rate': 0.15
}

#学習
evaluationResults = {}
lgbModel = lgb.train(train_set=lgbTrain,
                     params=lgbParams,
                     valid_sets=[lgbTrain, lgbTest], 
                     valid_names=['Train', 'Test'],
                     evals_result=evaluationResults,
                     num_boost_round=500,
                     early_stopping_rounds=100,
                     verbose_eval=20
                    )

optimum_boost_rounds = lgbModel.best_iteration
# Out:
# Training until validation scores don't improve for 100 rounds.
# [20]	Train's binary_logloss: 0.603591	Test's binary_logloss: 0.604226
# [40]	Train's binary_logloss: 0.575082	Test's binary_logloss: 0.570575
# [60]	Train's binary_logloss: 0.56959	Test's binary_logloss: 0.563646
# [80]	Train's binary_logloss: 0.560242	Test's binary_logloss: 0.552927
# [100]	Train's binary_logloss: 0.556166	Test's binary_logloss: 0.5482
# [120]	Train's binary_logloss: 0.55528	Test's binary_logloss: 0.547171
# [140]	Train's binary_logloss: 0.543872	Test's binary_logloss: 0.53428
# [160]	Train's binary_logloss: 0.542823	Test's binary_logloss: 0.532965
# [180]	Train's binary_logloss: 0.524177	Test's binary_logloss: 0.512307
# [200]	Train's binary_logloss: 0.515526	Test's binary_logloss: 0.502724
# [220]	Train's binary_logloss: 0.51335	Test's binary_logloss: 0.500315
# [240]	Train's binary_logloss: 0.508919	Test's binary_logloss: 0.495335
# [260]	Train's binary_logloss: 0.504353	Test's binary_logloss: 0.490202
# [280]	Train's binary_logloss: 0.49982	Test's binary_logloss: 0.48513
# [300]	Train's binary_logloss: 0.497848	Test's binary_logloss: 0.482905
# [320]	Train's binary_logloss: 0.494386	Test's binary_logloss: 0.479095
# [340]	Train's binary_logloss: 0.49429	Test's binary_logloss: 0.478917
# [360]	Train's binary_logloss: 0.495057	Test's binary_logloss: 0.479893
# [380]	Train's binary_logloss: 0.495178	Test's binary_logloss: 0.479913
# [400]	Train's binary_logloss: 0.488469	Test's binary_logloss: 0.472623
# [420]	Train's binary_logloss: 0.486233	Test's binary_logloss: 0.470078
# [440]	Train's binary_logloss: 0.480305	Test's binary_logloss: 0.463618
# [460]	Train's binary_logloss: 0.47789	Test's binary_logloss: 0.461072
# [480]	Train's binary_logloss: 0.471164	Test's binary_logloss: 0.453801
# [500]	Train's binary_logloss: 0.4698	Test's binary_logloss: 0.452795
# Did not meet early stopping. Best iteration is:
# [493]	Train's binary_logloss: 0.469174	Test's binary_logloss: 0.451987

# %%
fig, axs = plt.subplots(1, 2, figsize=[15, 4])

# Plot the log loss during training
axs[0].plot(evaluationResults['Train']['binary_logloss'], label='Train')
axs[0].plot(evaluationResults['Test']['binary_logloss'], label='Test')
axs[0].set_ylabel('Log loss')
axs[0].set_xlabel('Boosting round')
axs[0].set_title('Training performance')
axs[0].legend()

# Plot feature importance
importances = pd.DataFrame({'features': lgbModel.feature_name(), 
                            'importance': lgbModel.feature_importance()}).sort_values('importance', ascending=False)
axs[1].bar(x=np.arange(len(importances)), height=importances['importance'])
axs[1].set_xticks(np.arange(len(importances)))
axs[1].set_xticklabels(importances['features'])
axs[1].set_ylabel('Feature importance (# times used to split)')
axs[1].set_title('Feature importance')

plt.show()

# %%
preds = np.round(lgbModel.predict(X_test))
print('Accuracy score = \t {}'.format(accuracy_score(y_test, preds)))
print('Precision score = \t {}'.format(precision_score(y_test, preds)))
print('Recall score =   \t {}'.format(recall_score(y_test, preds)))
print('F1 score =      \t {}'.format(f1_score(y_test, preds)))
# Out:
# Accuracy score = 	 0.7988826815642458
# Precision score = 	 0.8
# Recall score =   	 0.6666666666666666
# F1 score =      	 0.7272727272727272

# %%
#予測用datasetで予測
lgbFinal = lgb.train(train_set=lgbFinalTrain,
                      params=lgbParams,
                      num_boost_round=optimum_boost_rounds,
                      verbose_eval=0
                      )

lgbPred = np.round(lgbFinal.predict(test)).astype(int)

# %%
# テスト値を再読み込みして，randomForestでクラス分類したカラムを追加
df_out = pd.read_csv("./data/test.csv")
lgbPred = pd.Series(lgbPred)
df_out["Survived"] = lgbPred

# outputディレクトリに出力する
df_out[["PassengerId","Survived"]].to_csv("./data/lgbSubmission4.csv",index=False)

# %%
#PCA
from sklearn.decomposition import PCA
import seaborn as sns

# %%
sns.pairplot(trainFeatures)

# %%
#次元圧縮
pca = PCA(n_components=5)
trainFeatures = pca.fit_transform(trainFeatures.values)
trainFeatures = pd.DataFrame(trainFeatures)

# %%
trainFeatures.head()
# Out:
#            0         1         2         3         4
# 0 -25.150561 -7.067572  0.293596 -0.338839 -0.576866
# 1  39.296118  7.305017 -0.022035  1.560158 -0.428147
# 2 -24.374808 -3.070564 -0.442947 -0.421480  0.052937
# 3  21.035728  4.774630  0.269580 -0.313863 -0.548639
# 4 -24.020354  5.922725 -0.251435 -0.487822 -0.106354

# %%
plt.Figure()
plt.scatter(trainFeatures[:,0], trainFeatures[:,1], trainFeatures[:,2])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-48-36bbed9d347b> in <module>()
#       1 plt.Figure()
# ----> 2 plt.scatter(trainFeatures[:,0], trainFeatures[:,1], trainFeatures[:,2])
#       3 plt.show()
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2137             return self._getitem_multilevel(key)
#    2138         else:
# -> 2139             return self._getitem_column(key)
#    2140
#    2141     def _getitem_column(self, key):
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    2144         # get column
#    2145         if self.columns.is_unique:
# -> 2146             return self._get_item_cache(key)
#    2147
#    2148         # duplicate columns & possible reduce dimensionality
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    1838         """Return the cached item, item represents a label indexer."""
#    1839         cache = self._item_cache
# -> 1840         res = cache.get(item)
#    1841         if res is None:
#    1842             values = self._data.get(item)
#
# TypeError: unhashable type: 'slice'

# %%
#light gbm 用データ分割
X_train, X_test, y_train, y_test = train_test_split(trainFeatures, trainLabels, test_size=0.2, random_state=72)

#モデル用dataset生成
import lightgbm as lgb
lgbTrain = lgb.Dataset(X_train, y_train)
lgbTest = lgb.Dataset(X_test, y_test)
lgbFinalTrain = lgb.Dataset(trainFeatures, trainLabels)

# %%
#light gbm

lgbParams = {
    'boosting': 'dart',          # dart (drop out trees) often performs better
    'application': 'binary',     # Binary classification
    'learning_rate': 0.02,       # Learning rate, controls size of a gradient descent step
    'min_data_in_leaf': 20,      # Data set is quite small so reduce this a bit
    'feature_fraction': 0.7,     # Proportion of features in each boost, controls overfitting
    'num_leaves': 41,            # Controls size of tree since LGBM uses leaf wise splits
    'metric': 'binary_logloss',  # Area under ROC curve as the evaulation metric
    'drop_rate': 0.15
}

#学習
evaluationResults = {}
lgbModel = lgb.train(train_set=lgbTrain,
                     params=lgbParams,
                     valid_sets=[lgbTrain, lgbTest], 
                     valid_names=['Train', 'Test'],
                     evals_result=evaluationResults,
                     num_boost_round=500,
                     early_stopping_rounds=100,
                     verbose_eval=20
                    )

optimum_boost_rounds = lgbModel.best_iteration
# Out:
# Training until validation scores don't improve for 100 rounds.
# [20]	Train's binary_logloss: 0.582257	Test's binary_logloss: 0.615236
# [40]	Train's binary_logloss: 0.538267	Test's binary_logloss: 0.580033
# [60]	Train's binary_logloss: 0.528664	Test's binary_logloss: 0.572229
# [80]	Train's binary_logloss: 0.513949	Test's binary_logloss: 0.564145
# [100]	Train's binary_logloss: 0.508672	Test's binary_logloss: 0.561326
# [120]	Train's binary_logloss: 0.499956	Test's binary_logloss: 0.555831
# [140]	Train's binary_logloss: 0.486818	Test's binary_logloss: 0.548842
# [160]	Train's binary_logloss: 0.490362	Test's binary_logloss: 0.550886
# [180]	Train's binary_logloss: 0.467626	Test's binary_logloss: 0.538458
# [200]	Train's binary_logloss: 0.45234	Test's binary_logloss: 0.529448
# [220]	Train's binary_logloss: 0.44436	Test's binary_logloss: 0.526344
# [240]	Train's binary_logloss: 0.429511	Test's binary_logloss: 0.520379
# [260]	Train's binary_logloss: 0.420221	Test's binary_logloss: 0.518645
# [280]	Train's binary_logloss: 0.410887	Test's binary_logloss: 0.515325
# [300]	Train's binary_logloss: 0.404453	Test's binary_logloss: 0.512501
# [320]	Train's binary_logloss: 0.398447	Test's binary_logloss: 0.511105
# [340]	Train's binary_logloss: 0.394557	Test's binary_logloss: 0.509813
# [360]	Train's binary_logloss: 0.39957	Test's binary_logloss: 0.512322
# [380]	Train's binary_logloss: 0.392659	Test's binary_logloss: 0.510455
# [400]	Train's binary_logloss: 0.385522	Test's binary_logloss: 0.507755
# [420]	Train's binary_logloss: 0.378477	Test's binary_logloss: 0.504898
# [440]	Train's binary_logloss: 0.370147	Test's binary_logloss: 0.503619
# [460]	Train's binary_logloss: 0.365599	Test's binary_logloss: 0.503146
# [480]	Train's binary_logloss: 0.351677	Test's binary_logloss: 0.500078
# [500]	Train's binary_logloss: 0.351531	Test's binary_logloss: 0.500665
# Did not meet early stopping. Best iteration is:
# [493]	Train's binary_logloss: 0.35072	Test's binary_logloss: 0.500711

# %%
fig, axs = plt.subplots(1, 2, figsize=[15, 4])

# Plot the log loss during training
axs[0].plot(evaluationResults['Train']['binary_logloss'], label='Train')
axs[0].plot(evaluationResults['Test']['binary_logloss'], label='Test')
axs[0].set_ylabel('Log loss')
axs[0].set_xlabel('Boosting round')
axs[0].set_title('Training performance')
axs[0].legend()

# Plot feature importance
importances = pd.DataFrame({'features': lgbModel.feature_name(), 
                            'importance': lgbModel.feature_importance()}).sort_values('importance', ascending=False)
axs[1].bar(x=np.arange(len(importances)), height=importances['importance'])
axs[1].set_xticks(np.arange(len(importances)))
axs[1].set_xticklabels(importances['features'])
axs[1].set_ylabel('Feature importance (# times used to split)')
axs[1].set_title('Feature importance')

plt.show()

# %%
preds = np.round(lgbModel.predict(X_test))
print('Accuracy score = \t {}'.format(accuracy_score(y_test, preds)))
print('Precision score = \t {}'.format(precision_score(y_test, preds)))
print('Recall score =   \t {}'.format(recall_score(y_test, preds)))
print('F1 score =      \t {}'.format(f1_score(y_test, preds)))
# Out:
# Accuracy score = 	 0.7821229050279329
# Precision score = 	 0.7538461538461538
# Recall score =   	 0.6805555555555556
# F1 score =      	 0.7153284671532848
